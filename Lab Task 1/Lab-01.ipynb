# %% [markdown]
# # Question 1: Student Grade System
# Write a Python program that takes a student’s name and marks as input and prints the grade according to the following criteria:
# • Marks ≥ 85 → Grade A
# • Marks ≥ 70 → Grade B
# • Marks ≥ 50 → Grade C
# • Marks < 50 → Fail

# %%
def main():
    name = input("Enter student name: ").strip()
    marks = int(input("Enter marks: "))

    if marks >= 85:
        grade = "A"
    elif marks >= 70:
        grade = "B"
    elif marks >= 50:
        grade = "C"
    else:
        grade = "Fail"

    print(f"Student Name: {name}")
    print(f"Marks: {marks}")
    print(f"Grade: {grade}")

if __name__ == "__main__":
    main()
# Out:
# Enter student name: Rayyan Aamir
# Enter marks: 85
# Student Name: Rayyan Aamir
# Marks: 85
# Grade: A

# %% [markdown]
# # Question 2: Even Number Counter
# Write a Python program that takes a number n from the user and prints all even numbers from 1 to n. Also display the total count of even numbers.

# %%
def main():
    n = int(input("Enter a number: "))
    count = 0

    print("Even numbers: ", end = "")
    for i in range(1, n+1):
        if i % 2 == 0:
            print(i, end = " ")
            count = count + 1

    print(f"\nTotal even numbers: {count}")

if __name__ == "__main__":
    main()
# Out:
# Enter a number: 15
# Even numbers: 2 4 6 8 10 12 14
# Total even numbers: 7

# %% [markdown]
# # Question 3: Student Record Using Dictionary
# Write a Python program that stores the names and marks of three students in a dictionary and then displays all student records.

# %%
def main():
    students = {}
    for i in range(3):
        name = input("Enter student name: ").strip()
        marks = int(input("Enter marks: "))
        students[name] = marks

    print("\nStudent Records:")
    for name, marks in students.items():
        print(f"{name}: {marks}")

if __name__ == "__main__":
    main()
# Out:
# Enter student name: Rayyan Aamir
# Enter marks: 78
# Enter student name: Murtaza Hunaid
# Enter marks: 90
# Enter student name: Hammad Haider
# Enter marks: 82
#
# Student Records:
# Rayyan Aamir: 78
# Murtaza Hunaid: 90
# Hammad Haider: 82

# %% [markdown]
# # Question 4: Menu-Driven Calculator
# Write a Python program using a while loop that shows the following menu repeatedly until the user exits:
# 1. Add two numbers
# 2. Subtract two numbers
# 3. Exit

# %%
def main():
    while True:
        print("1. Add two numbers")
        print("2. Subtract two numbers")
        print("3. Exit")
        choice = int(input("Enter your choice: "))

        if choice == 1:
            num1 = int(input("Enter first number: "))
            num2 = int(input("Enter second number: "))
            result = num1 + num2
            print(f"Result: {result}")
        elif choice == 2:
            num1 = int(input("Enter first number: "))
            num2 = int(input("Enter second number: "))
            result = num1 - num2
            print(f"Result: {result}")
        elif choice == 3:
            print("Exiting...")
            break
        else:
            print("Invalid choice!")

    print("Goodbye!")

if __name__ == "__main__":
    main()
# Out:
# 1. Add two numbers
# 2. Subtract two numbers
# 3. Exit
# Enter your choice: 1
# Enter first number: 7
# Enter second number: 6
# Result: 13
# 1. Add two numbers
# 2. Subtract two numbers
# 3. Exit
# Enter your choice: 2
# Enter first number: 10
# Enter second number: 4
# Result: 6
# 1. Add two numbers
# 2. Subtract two numbers
# 3. Exit
# Enter your choice: 3
# Exiting...
# Goodbye!

# %% [markdown]
# # Question 5: Average Marks Using Function
# Write a Python function named calculate_average() that takes a list of marks and returns the average marks.

# %%
def calculate_average(marks):
    total = 0
    for mark in marks:
        total += mark
    return total / len(marks)

def main():
    n = int(input("Enter the number of marks: "))
    marks = []

    for i in range(n):
        mark = int(input(f"Enter marks {i + 1}: "))
        marks.append(mark)

    print(f"\nMarks: {marks}")
    print(f"Average Marks: {calculate_average(marks):.1f}")

if __name__ == "__main__":
    main()
# Out:
# Enter the number of marks: 3
# Enter marks 1: 70
# Enter marks 2: 80
# Enter marks 3: 90
#
# Marks: [70, 80, 90]
# Average Marks: 80.0
